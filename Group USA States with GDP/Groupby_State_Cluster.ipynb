# %% [markdown]
# <a href="https://colab.research.google.com/github/HughYau/Research-with-Python/blob/main/Group%20USA%20States%20with%20GDP/Groupby_State_Cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
state_adjancy_T = pd.read_excel(r"D:\Application\WeChat\Documents\WeChat Files\wxid_852lwrk6lh2812\FileStorage\File\2022-01\state adjacency.xlsx")
state_adjancy = pd.read_excel(r"D:\Application\WeChat\Documents\WeChat Files\wxid_852lwrk6lh2812\FileStorage\File\2022-01\state adjacency matrix(1).xls")
state_income = pd.read_excel(r"D:\Application\WeChat\Documents\WeChat Files\wxid_852lwrk6lh2812\FileStorage\File\2022-01\state personal income.xlsx")
k = 5
kmeans = KMeans(n_clusters=k)
X = state_income['LP1_tot_pinc'].to_numpy()
X = X.reshape(-1,1)
y_pred = kmeans.fit_predict(X)
state_income['group'] = y_pred
plt.scatter(X,y_pred)
state_income.to_excel(r'D:\Work\state_gdp_cluster.xlsx')

# %%
state_adjancy['AL']
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: AL, dtype: bool

# %%
state_income[state_income['group'] == 3]
# Out:
#          statename state_abbr  state_num  timeyq  LP1_tot_pinc    PI_USDsa  \
# 8          Florida         FL         12  1972q1   36500000000  8690000000
# 9          Georgia         GA         13  1972q1   20200000000  4820000000
# 13         Indiana         IN         18  1972q1   24200000000  5770000000
# 19        Maryland         MD         24  1972q1   23400000000  5580000000
# 20   Massachusetts         MA         25  1972q1   30800000000  7330000000
# 24        Missouri         MO         29  1972q1   21900000000  5210000000
# 32  North Carolina         NC         37  1972q1   21500000000  5110000000
# 45        Virginia         VA         51  1972q1   24100000000  5740000000
# 48       Wisconsin         WI         55  1972q1   21100000000  5020000000
#
#     pce_decimal  group
# 8       0.23812      3
# 9       0.23812      3
# 13      0.23812      3
# 19      0.23812      3
# 20      0.23812      3
# 24      0.23812      3
# 32      0.23812      3
# 45      0.23812      3
# ...

# %%
work1
# Out:
#        statename state_abbr  state_num  timeyq  LP1_tot_pinc     PI_USDsa  \
# 12      Illinois         IL         17  1972q1   61200000000  14600000000
# 21      Michigan         MI         26  1972q1   45200000000  10800000000
# 29    New Jersey         NJ         34  1972q1   41800000000   9950000000
# 34          Ohio         OH         39  1972q1   51900000000  12400000000
# 37  Pennsylvania         PA         42  1972q1   57600000000  13700000000
# 42         Texas         TX         48  1972q1   51400000000  12200000000
#
#     pce_decimal  group
# 12      0.23812      2
# 21      0.23812      2
# 29      0.23812      2
# 34      0.23812      2
# 37      0.23812      2
# 42      0.23812      2

# %%
'AK' in state_adjancy_T['AL'].values
# Out:
# False

# %%
work1 = state_income[state_income['group'] == 2]
sa = work1.state_abbr

# %%
work1.iloc[2].group
# Out:
# 2

# %%
g = 0
work1 = work[work['group'] == 0].copy()
work1['group_final'] = -1
sa = work1.state_abbr.values
for i in range(len(sa)):
    if work1.iloc[i].group_final == -1:
        work1.iloc[i].group_final = g
        g = g+1
    for j in range(i+1,len(sa)):
        if sa[j] in state_adjancy_T[sa[i]].values:
            work1.iloc[j].group_final = work1.iloc[i].group_final
# Out:
# D:\Application\Anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# <ipython-input-314-101c9f29a212>:10: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if sa[j] in state_adjancy_T[sa[i]].values:

# %%
work1
# Out:
#         statename state_abbr  state_num  timeyq  LP1_tot_pinc    PI_USDsa  \
# 1          Alaska         AK          2  1972q1    2170000000   516000000
# 3        Arkansas         AR          5  1972q1    7010000000  1670000000
# 7        Delaware         DE         10  1972q1    3150000000   750000000
# 10         Hawaii         HI         15  1972q1    5040000000  1200000000
# 11          Idaho         ID         16  1972q1    3220000000   766000000
# 18          Maine         ME         23  1972q1    4320000000  1030000000
# 23    Mississippi         MS         28  1972q1    7630000000  1820000000
# 25        Montana         MT         30  1972q1    3160000000   752000000
# 26       Nebraska         NE         31  1972q1    7070000000  1680000000
# 27         Nevada         NV         32  1972q1    3070000000   732000000
# 28  New Hampshire         NH         33  1972q1    3670000000   873000000
# 30     New Mexico         NM         35  1972q1    4320000000  1030000000
# ...

# %%
work = state_income.copy()
work['group_final'] = -1
g = 0
for i in range(5):
    work1 = work[work['group'] == i]
    sa = work1.state_abbr.values
    for i in range(len(sa)):
        if work1.iloc[i].group_final == -1:
            work1.iloc[i].group_final = g
            g = g+1
        for j in range(i+1,len(sa)):
            if sa[j] in state_adjancy_T[sa[i]].values:
                work1.iloc[j].group_final = work1.iloc[i].group_final
# Out:
# D:\Application\Anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# <ipython-input-301-7a2520d72347>:12: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if sa[j] in state_adjancy_T[sa[i]].values:
# D:\Application\Anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# D:\Application\Anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# ...

# %%
work1['group_final'].value_counts()
# Out:
# -1    14
# Name: group_final, dtype: int64

# %%
work = pd.merge(state_income,state_adjancy,how = 'left',on = 'state_abbr')
work['group_final'] = -1
g = 0
for i in range(50):
    sa = work.iloc[i,1]
    print(sa+":",end = '')
    for j in work.iloc[i,8:16]:
        if pd.isnull(j) == False:
            if work.loc[work['state_abbr'] == sa,'group'].tolist() == work.loc[work['state_abbr'] == j,'group'].tolist():
                print(j,end = ',')
        else:
            break
    print('\n')
# Out:
# AL:TN,
#
# AK:
#
# AZ:CO,
#
# AR:MS,
#
# CA:
#
# CO:KS,OK,AZ,
#
# CT:
#
# DE:
#
# FL:GA,
#
# GA:FL,NC,
#
# HI:
#
# ID:MT,WY,UT,NV,
#
# IL:
#
# IN:
#
# IA:MN,
#
# KS:OK,CO,
#
# KY:TN,
#
# LA:
#
# ME:NH,
#
# MD:VA,
#
# MA:
#
# MI:OH,
#
# MN:IA,
#
# MS:AR,
#
# MO:
#
# MT:ND,SD,WY,ID,
#
# NE:SD,WY,
#
# NV:ID,UT,
#
# NH:VT,ME,
#
# NJ:PA,
#
# NM:UT,
#
# NY:
#
# NC:VA,GA,
#
# ND:SD,MT,
#
# OH:PA,MI,
#
# OK:KS,CO,
#
# OR:WA,
#
# PA:NJ,OH,
#
# RI:
#
# SC:
#
# SD:ND,NE,WY,MT,
#
# TN:KY,AL,
#
# TX:
#
# UT:ID,WY,NM,NV,
#
# VT:NH,
#
# VA:NC,MD,
#
# WA:OR,
#
# WV:
#
# WI:
#
# WY:MT,SD,NE,UT,ID,

# %%
work = pd.merge(state_income,state_adjancy,how = 'left',on = 'state_abbr')
work['group_final'] = -1
g = 0
for i in range(50):
    sa = work.iloc[i,1]
    for j in work.iloc[i,8:16]:
        if pd.isnull(j) == False:
            if work.loc[work['state_abbr'] == sa,'group'].tolist() == work.loc[work['state_abbr'] == j,'group'].tolist():
                if (work.loc[work['state_abbr'] == sa,'group_final'].values == -1) and (work.loc[work['state_abbr'] == j,'group_final'].values == -1):
                    work.loc[work['state_abbr'] == sa,'group_final'] = g
                    work.loc[work['state_abbr'] == j,'group_final'] = g
                    g = g + 1 
                elif work.loc[work['state_abbr'] == sa,'group_final'].values == -1:
                    work.loc[work['state_abbr'] == sa,'group_final'] = work.loc[work['state_abbr'] == j,'group_final']
                elif work.loc[work['state_abbr'] == j,'group_final'].values == -1:
                    work.loc[work['state_abbr'] == j,'group_final'] = work.loc[work['state_abbr'] == sa,'group_final']

# %%
work['group_final'].value_counts()
# Out:
# -1.0     16
#  0.0      2
#  3.0      2
#  7.0      2
#  2.0      2
#  9.0      2
#  5.0      2
#  6.0      2
#  10.0     2
#  4.0      2
#  8.0      2
#  1.0      2
# Name: group_final, dtype: int64

# %%
work
# Out:
#          statename state_abbr  state_num  timeyq  LP1_tot_pinc     PI_USDsa  \
# 0          Alabama         AL          1  1972q1   13100000000   3130000000
# 1           Alaska         AK          2  1972q1    2170000000    516000000
# 2          Arizona         AZ          4  1972q1    9470000000   2250000000
# 3         Arkansas         AR          5  1972q1    7010000000   1670000000
# 4       California         CA          6  1972q1  118000000000  28000000000
# 5         Colorado         CO          8  1972q1   12000000000   2860000000
# 6      Connecticut         CT          9  1972q1   17900000000   4250000000
# 7         Delaware         DE         10  1972q1    3150000000    750000000
# 8          Florida         FL         12  1972q1   36500000000   8690000000
# 9          Georgia         GA         13  1972q1   20200000000   4820000000
# 10          Hawaii         HI         15  1972q1    5040000000   1200000000
# ...

# %%
for i in state_adjancy.iloc[1,1:]:
    print(i)
# Out:
# MS
# TN
# GA
# FL
# nan
# nan
# nan
# nan

# %%
state_adjancy.iloc[1]
# Out:
# state_abbr     AL
# Unnamed: 1     MS
# Unnamed: 2     TN
# Unnamed: 3     GA
# Unnamed: 4     FL
# Unnamed: 5    NaN
# Unnamed: 6    NaN
# Unnamed: 7    NaN
# Unnamed: 8    NaN
# Name: 1, dtype: object

# %%
state_income.plot.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-f1625e6d75a0> in <module>
# ----> 1 state_income['LP1_tot_pinc'].plot.scatter()
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
X = state_income['LP1_tot_pinc'].to_numpy()
X = X.reshape(-1,1)

# %%
X
# Out:
# array([[ 13100000000],
#        [  2170000000],
#        [  9470000000],
#        [  7010000000],
#        [118000000000],
#        [ 12000000000],
#        [ 17900000000],
#        [  3150000000],
#        [ 36500000000],
#        [ 20200000000],
#        [  5040000000],
#        [  3220000000],
#        [ 61200000000],
#        [ 24200000000],
#        [ 13000000000],
#        [ 10800000000],
#        [ 12800000000],
#        [ 13900000000],
#        [  4320000000],
#        [ 23400000000],
#        [ 30800000000],
#        [ 45200000000],
#        [ 18300000000],
#        [  7630000000],
#        [ 21900000000],
#        [  3160000000],
#        [  7070000000],
#        [  3070000000],
#        [  3670000000],
#        [ 41800000000],
#        [  4320000000],
#        [104000000000],
#        [ 21500000000],
#        [  2750000000],
#        [ 51900000000],
#        [ 11300000000],
#        [ 10500000000],
#        [ 57600000000],
#        [  4840000000],
#        [ 10300000000],
# ...

# %%
from sklearn.cluster import KMeans
k = 6
kmeans = KMeans(n_clusters=k)
y_pred = kmeans.fit_predict(X)
plt.scatter(X,y_pred)

# %%
state_income['group'] = y_pred

# %%
work = pd.merge(state_income,state_adjancy,how = 'left',on = 'state_abbr')

# %%
work
# Out:
#          statename state_abbr  state_num  timeyq  LP1_tot_pinc     PI_USDsa  \
# 0          Alabama         AL          1  1972q1   13100000000   3130000000
# 1           Alaska         AK          2  1972q1    2170000000    516000000
# 2          Arizona         AZ          4  1972q1    9470000000   2250000000
# 3         Arkansas         AR          5  1972q1    7010000000   1670000000
# 4       California         CA          6  1972q1  118000000000  28000000000
# 5         Colorado         CO          8  1972q1   12000000000   2860000000
# 6      Connecticut         CT          9  1972q1   17900000000   4250000000
# 7         Delaware         DE         10  1972q1    3150000000    750000000
# 8          Florida         FL         12  1972q1   36500000000   8690000000
# 9          Georgia         GA         13  1972q1   20200000000   4820000000
# 10          Hawaii         HI         15  1972q1    5040000000   1200000000
# ...

# %%
work['group_final'].value_counts()
# Out:
#  0    12
#  1    12
# -1     8
#  9     4
#  5     3
#  7     3
#  8     3
#  3     2
#  2     1
#  4     1
#  6     1
# Name: group_final, dtype: int64

# %%
work
# Out:
#          statename state_abbr  state_num  timeyq  LP1_tot_pinc     PI_USDsa  \
# 0          Alabama         AL          1  1972q1   13100000000   3130000000
# 1           Alaska         AK          2  1972q1    2170000000    516000000
# 2          Arizona         AZ          4  1972q1    9470000000   2250000000
# 3         Arkansas         AR          5  1972q1    7010000000   1670000000
# 4       California         CA          6  1972q1  118000000000  28000000000
# 5         Colorado         CO          8  1972q1   12000000000   2860000000
# 6      Connecticut         CT          9  1972q1   17900000000   4250000000
# 7         Delaware         DE         10  1972q1    3150000000    750000000
# 8          Florida         FL         12  1972q1   36500000000   8690000000
# 9          Georgia         GA         13  1972q1   20200000000   4820000000
# 10          Hawaii         HI         15  1972q1    5040000000   1200000000
# ...

# %%
state_adjancy.iloc[1]
# Out:
# StateCode            AL
# NeighborStateCode    FL
# Name: 1, dtype: object

# %%
from sklearn.metrics import silhouette_score
for k in range(2,15):
    kmeans = KMeans(n_clusters=k)
    y_pred = kmeans.fit_predict(X)
    print("聚类数为",k,"得分为：",silhouette_score(X, kmeans.labels_))
# Out:
# 聚类数为 2 得分为： 0.7433655913723879
# 聚类数为 3 得分为： 0.7299496749301028
# 聚类数为 4 得分为： 0.637452017726662
# 聚类数为 5 得分为： 0.6210113836592162
# 聚类数为 6 得分为： 0.6255180000005028
# 聚类数为 7 得分为： 0.6312457455182605
# 聚类数为 8 得分为： 0.5959315899604922
# 聚类数为 9 得分为： 0.617411917781599
# 聚类数为 10 得分为： 0.6150337271668226
# 聚类数为 11 得分为： 0.581008560213491
# 聚类数为 12 得分为： 0.5769643182224886
# 聚类数为 13 得分为： 0.5750301242167227
# 聚类数为 14 得分为： 0.6036296873637137

# %%
state_adjancy
# Out:
#     StateCode NeighborStateCode
# 0          AK                WA
# 1          AL                FL
# 2          AL                GA
# 3          AL                MS
# 4          AL                TN
# ..        ...               ...
# 106        PA                WV
# 107        SD                WY
# 108        TN                VA
# 109        UT                WY
# 110        VA                WV
#
# [111 rows x 2 columns]
